# %%
contestPath = '../assets/data/7/submitions.html'

# %%
from xml.dom import minidom
from dateutil.parser import parse
import re

# %%
dom = minidom.parse(contestPath)

# %%
contestantDom = dom.getElementsByTagName('tr')

# %%
problemsDom = contestantDom[0]
problems = [x.firstChild.data for x in problemsDom.getElementsByTagName('th')][2:-2]

# %%
contestantsDom = contestantDom[1:]

# %%
hailoDom = contestantsDom[0]
def parseDom(dom):
    return [x.firstChild.data for x in dom.getElementsByTagName('td')[1:-2]]

# %%
scoreboard = map(parseDom, contestantsDom)

# %%
handle = [x[0] for x in scoreboard]
handle
# Out:
# [u'Jose Mallma Leon',
#  u'Enrique',
#  u'Robert Alonso',
#  u'Rodrigo Horruitiner',
#  u'Oscar Vega Huayanay',
#  u'Jesus',
#  u'Keyvhinng',
#  u'Sebasti\xe1n',
#  u'Paul Luyo',
#  u'Jesus Figueroa Curo',
#  u'Juanjose Tenorio',
#  u'Daniel',
#  u'Angel Napa',
#  u'Rodrigo L\xf3pez']

# %%
def genSubmitions(substr):
    if substr == '-':
        return None
    else:
        sp = substr.split()
        last = sp[-1]
        times = int(re.findall('\d+', last)[0])
        datestr = ' '.join(sp[:-1])
        if not datestr:
            return None
        return (datestr, times)

# %%
cured = [
    'hailo',
    'kvaleriano',
    'Robert_Alonso',
    'itu',
    'Rxcso',
    'jael',
    'kirasam',
    'Slsvcn',
    'Lucas97',
    'jafc',
    'juanjo12x',
    'Dan212P',
    'Gerard901',
    'The_Blitz',
]

# %%
submissions = []
for idy, row in enumerate(scoreboard):
    name = cured[idy]
    for idx, problemStr in enumerate(row[1:]):
        sub = genSubmitions(problemStr)
        if sub:
            date = sub[0]
            watimes = sub[0]
            submissions.append(Submition(
               handle = name,
               veredict = Veredict.getVeredict('accepted'),
               problem = problems[idx],
               seconds = (parse(date) - parse('2014-09-11 19:05:00')).total_seconds()
            ))

# %%
submissions.sort(key= lambda x: x.seconds)

# %%
submissions
# Out:
# [Submition[Rxcso, SP714P01, 216.0, 1],
#  Submition[Slsvcn, SP714P01, 219.0, 1],
#  Submition[Robert_Alonso, SP714P01, 470.0, 1],
#  Submition[kvaleriano, SP714P05, 502.0, 1],
#  Submition[juanjo12x, SP714P01, 571.0, 1],
#  Submition[Lucas97, SP714P01, 591.0, 1],
#  Submition[hailo, SP714P01, 641.0, 1],
#  Submition[kirasam, SP714P01, 747.0, 1],
#  Submition[jafc, SP714P02, 975.0, 1],
#  Submition[Slsvcn, SP714P06, 1037.0, 1],
#  Submition[Gerard901, SP714P01, 1056.0, 1],
#  Submition[Lucas97, SP714P02, 1164.0, 1],
#  Submition[kvaleriano, SP714P12, 1254.0, 1],
#  Submition[jael, SP714P03, 1279.0, 1],
#  Submition[hailo, SP714P05, 1295.0, 1],
#  Submition[kvaleriano, SP714P06, 1447.0, 1],
#  Submition[jael, SP714P01, 1463.0, 1],
#  Submition[hailo, SP714P02, 1624.0, 1],
#  Submition[kirasam, SP714P05, 1715.0, 1],
#  Submition[Rxcso, SP714P05, 1840.0, 1],
#  Submition[Slsvcn, SP714P15, 1937.0, 1],
#  Submition[kvaleriano, SP714P14, 1956.0, 1],
#  Submition[hailo, SP714P03, 2096.0, 1],
#  Submition[Robert_Alonso, SP714P06, 2123.0, 1],
#  Submition[Rxcso, SP714P06, 2137.0, 1],
#  Submition[kirasam, SP714P06, 2185.0, 1],
#  Submition[jael, SP714P05, 2254.0, 1],
#  Submition[juanjo12x, SP714P03, 2293.0, 1],
#  Submition[hailo, SP714P04, 2362.0, 1],
#  Submition[Rxcso, SP714P08, 2426.0, 1],
#  Submition[kvaleriano, SP714P02, 2444.0, 1],
#  Submition[Robert_Alonso, SP714P15, 2507.0, 1],
#  Submition[Dan212P, SP714P02, 2523.0, 1],
#  Submition[jael, SP714P06, 2590.0, 1],
#  Submition[kirasam, SP714P13, 2658.0, 1],
#  Submition[hailo, SP714P06, 2685.0, 1],
#  Submition[Rxcso, SP714P09, 2716.0, 1],
#  Submition[Slsvcn, SP714P14, 2729.0, 1],
#  Submition[kvaleriano, SP714P08, 2838.0, 1],
#  Submition[Rxcso, SP714P10, 2884.0, 1],
#  Submition[Robert_Alonso, SP714P08, 2908.0, 1],
#  Submition[hailo, SP714P15, 2957.0, 1],
#  Submition[The_Blitz, SP714P01, 3067.0, 1],
#  Submition[Rxcso, SP714P11, 3085.0, 1],
#  Submition[kirasam, SP714P14, 3149.0, 1],
#  Submition[jafc, SP714P01, 3206.0, 1],
#  Submition[hailo, SP714P09, 3264.0, 1],
#  Submition[Robert_Alonso, SP714P10, 3337.0, 1],
#  Submition[Rxcso, SP714P12, 3350.0, 1],
#  Submition[The_Blitz, SP714P11, 3444.0, 1],
#  Submition[Lucas97, SP714P06, 3517.0, 1],
#  Submition[Slsvcn, SP714P09, 3598.0, 1],
#  Submition[Dan212P, SP714P06, 3646.0, 1],
#  Submition[hailo, SP714P08, 3659.0, 1],
#  Submition[jafc, SP714P06, 3661.0, 1],
#  Submition[itu, SP714P03, 3673.0, 1],
#  Submition[itu, SP714P04, 3686.0, 1],
#  Submition[itu, SP714P05, 3698.0, 1],
#  Submition[itu, SP714P06, 3711.0, 1],
#  Submition[itu, SP714P07, 3722.0, 1],
#  Submition[kvaleriano, SP714P01, 3760.0, 1],
#  Submition[kirasam, SP714P03, 3836.0, 1],
#  Submition[jael, SP714P08, 3853.0, 1],
#  Submition[Gerard901, SP714P06, 3947.0, 1],
#  Submition[Slsvcn, SP714P04, 3957.0, 1],
#  Submition[Robert_Alonso, SP714P09, 4007.0, 1],
#  Submition[hailo, SP714P07, 4021.0, 1],
#  Submition[kvaleriano, SP714P04, 4100.0, 1],
#  Submition[Rxcso, SP714P14, 4102.0, 1],
#  Submition[Lucas97, SP714P08, 4156.0, 1],
#  Submition[jael, SP714P09, 4187.0, 1],
#  Submition[hailo, SP714P10, 4192.0, 1],
#  Submition[kirasam, SP714P08, 4210.0, 1],
#  Submition[kvaleriano, SP714P11, 4332.0, 1],
#  Submition[hailo, SP714P11, 4342.0, 1],
#  Submition[Robert_Alonso, SP714P11, 4392.0, 1],
#  Submition[juanjo12x, SP714P14, 4416.0, 1],
#  Submition[Dan212P, SP714P15, 4416.0, 1],
#  Submition[jael, SP714P14, 4501.0, 1],
#  Submition[Rxcso, SP714P15, 4504.0, 1],
#  Submition[jafc, SP714P05, 4545.0, 1],
#  Submition[hailo, SP714P12, 4677.0, 1],
#  Submition[kvaleriano, SP714P13, 4684.0, 1],
#  Submition[Lucas97, SP714P09, 4716.0, 1],
#  Submition[kirasam, SP714P15, 4844.0, 1],
#  Submition[juanjo12x, SP714P02, 4887.0, 1],
#  Submition[Rxcso, SP714P03, 4905.0, 1],
#  Submition[Lucas97, SP714P10, 4935.0, 1],
#  Submition[Robert_Alonso, SP714P12, 4936.0, 1],
#  Submition[hailo, SP714P13, 4962.0, 1],
#  Submition[jael, SP714P11, 4968.0, 1],
#  Submition[kvaleriano, SP714P07, 5049.0, 1],
#  Submition[Rxcso, SP714P04, 5114.0, 1],
#  Submition[Dan212P, SP714P08, 5146.0, 1],
#  Submition[jafc, SP714P08, 5153.0, 1],
#  Submition[hailo, SP714P14, 5168.0, 1],
#  Submition[kvaleriano, SP714P09, 5264.0, 1],
#  Submition[jael, SP714P10, 5334.0, 1],
#  Submition[Robert_Alonso, SP714P02, 5352.0, 1],
#  Submition[itu, SP714P08, 5358.0, 1],
#  Submition[itu, SP714P09, 5373.0, 1],
#  Submition[Slsvcn, SP714P07, 5382.0, 1],
#  Submition[Lucas97, SP714P12, 5405.0, 1],
#  Submition[kirasam, SP714P12, 5449.0, 1],
#  Submition[Slsvcn, SP714P08, 5532.0, 1],
#  Submition[kvaleriano, SP714P15, 5540.0, 1],
#  Submition[itu, SP714P10, 5563.0, 1],
#  Submition[juanjo12x, SP714P05, 5641.0, 1],
#  Submition[jafc, SP714P09, 5680.0, 1],
#  Submition[Gerard901, SP714P08, 5685.0, 1],
#  Submition[itu, SP714P11, 5766.0, 1],
#  Submition[Robert_Alonso, SP714P04, 5776.0, 1],
#  Submition[Lucas97, SP714P13, 5862.0, 1],
#  Submition[Slsvcn, SP714P10, 5910.0, 1],
#  Submition[jael, SP714P13, 6000.0, 1],
#  Submition[itu, SP714P12, 6052.0, 1],
#  Submition[juanjo12x, SP714P04, 6094.0, 1],
#  Submition[kvaleriano, SP714P03, 6104.0, 1],
#  Submition[kirasam, SP714P11, 6184.0, 1],
#  Submition[jafc, SP714P14, 6216.0, 1],
#  Submition[Robert_Alonso, SP714P14, 6279.0, 1],
#  Submition[juanjo12x, SP714P10, 6317.0, 1],
#  Submition[itu, SP714P13, 6373.0, 1],
#  Submition[jael, SP714P15, 6512.0, 1],
#  Submition[Robert_Alonso, SP714P07, 6642.0, 1],
#  Submition[Lucas97, SP714P04, 6679.0, 1],
#  Submition[jafc, SP714P15, 6712.0, 1],
#  Submition[juanjo12x, SP714P06, 6742.0, 1],
#  Submition[itu, SP714P14, 6957.0, 1],
#  Submition[kvaleriano, SP714P10, 7095.0, 1],
#  Submition[Robert_Alonso, SP714P13, 7098.0, 1],
#  Submition[Gerard901, SP714P10, 7140.0, 1],
#  Submition[itu, SP714P15, 7188.0, 1]]

# %%
def splitEach(time_stream, seconds):
    end, start = seconds, 0
    ans, cur = [], []
    for idx, time in enumerate(time_stream): 
        if time.seconds > end:
            ans.append(cur)
            cur = [time]
            end += seconds
        else: 
            cur.append(time)
    if cur:
        ans.append(cur)
    return ans

# %%
map(len, splitEach(submissions, 350))
# Out:
# [2, 5, 3, 5, 4, 4, 8, 7, 7, 5, 12, 10, 9, 5, 10, 11, 7, 7, 4, 4, 4]

# %%
contest = Contest(cured, problems)
timer = 350
buckets = splitEach(submissions, timer)
scoreboards = []
for b in buckets:
    for s in b: 
        contest.apply(s)
    order = sorted(contest.getScoreboard(), key=lambda x: (-x.solved, x.penalty))
    scoreboards.append(order)
scoreboards
# Out:
# [[{Rxcso, 1, 3.6},
#   {Slsvcn, 1, 3.65},
#   {jael, 0, 0},
#   {Lucas97, 0, 0},
#   {Robert_Alonso, 0, 0},
#   {Dan212P, 0, 0},
#   {kirasam, 0, 0},
#   {The_Blitz, 0, 0},
#   {Gerard901, 0, 0},
#   {juanjo12x, 0, 0},
#   {hailo, 0, 0},
#   {jafc, 0, 0},
#   {kvaleriano, 0, 0},
#   {itu, 0, 0}],
#  [{Rxcso, 1, 3.6},
#   {Slsvcn, 1, 3.65},
#   {Robert_Alonso, 1, 7.83333333333},
#   {kvaleriano, 1, 8.36666666667},
#   {juanjo12x, 1, 9.51666666667},
#   {Lucas97, 1, 9.85},
#   {hailo, 1, 10.6833333333},
#   {jael, 0, 0},
#   {Dan212P, 0, 0},
#   {kirasam, 0, 0},
#   {The_Blitz, 0, 0},
#   {Gerard901, 0, 0},
#   {jafc, 0, 0},
#   {itu, 0, 0}],
#  [{Slsvcn, 2, 20.9333333333},
#   {Rxcso, 1, 3.6},
#   {Robert_Alonso, 1, 7.83333333333},
#   {kvaleriano, 1, 8.36666666667},
#   {juanjo12x, 1, 9.51666666667},
#   {Lucas97, 1, 9.85},
#   {hailo, 1, 10.6833333333},
#   {kirasam, 1, 12.45},
#   {jafc, 1, 16.25},
#   {jael, 0, 0},
#   {Dan212P, 0, 0},
#   {The_Blitz, 0, 0},
#   {Gerard901, 0, 0},
#   {itu, 0, 0}],
#  [{Slsvcn, 2, 20.9333333333},
#   {Lucas97, 2, 29.25},
#   {kvaleriano, 2, 29.2666666667},
#   {hailo, 2, 32.2666666667},
#   {Rxcso, 1, 3.6},
#   {Robert_Alonso, 1, 7.83333333333},
#   {juanjo12x, 1, 9.51666666667},
#   {kirasam, 1, 12.45},
#   {jafc, 1, 16.25},
#   {Gerard901, 1, 17.6},
#   {jael, 1, 21.3166666667},
#   {Dan212P, 0, 0},
#   {The_Blitz, 0, 0},
#   {itu, 0, 0}],
#  [{kvaleriano, 3, 53.3833333333},
#   {hailo, 3, 59.3333333333},
#   {Slsvcn, 2, 20.9333333333},
#   {Lucas97, 2, 29.25},
#   {kirasam, 2, 41.0333333333},
#   {jael, 2, 45.7},
#   {Rxcso, 1, 3.6},
#   {Robert_Alonso, 1, 7.83333333333},
#   {juanjo12x, 1, 9.51666666667},
#   {jafc, 1, 16.25},
#   {Gerard901, 1, 17.6},
#   {Dan212P, 0, 0},
#   {The_Blitz, 0, 0},
#   {itu, 0, 0}],
#  [{kvaleriano, 4, 85.9833333333},
#   {hailo, 4, 94.2666666667},
#   {Slsvcn, 3, 53.2166666667},
#   {Lucas97, 2, 29.25},
#   {Rxcso, 2, 34.2666666667},
#   {kirasam, 2, 41.0333333333},
#   {jael, 2, 45.7},
#   {Robert_Alonso, 1, 7.83333333333},
#   {juanjo12x, 1, 9.51666666667},
#   {jafc, 1, 16.25},
#   {Gerard901, 1, 17.6},
#   {Dan212P, 0, 0},
#   {The_Blitz, 0, 0},
#   {itu, 0, 0}],
#  [{kvaleriano, 5, 126.716666667},
#   {hailo, 5, 133.633333333},
#   {Rxcso, 4, 110.316666667},
#   {Slsvcn, 3, 53.2166666667},
#   {kirasam, 3, 77.45},
#   {jael, 3, 83.2666666667},
#   {Lucas97, 2, 29.25},
#   {Robert_Alonso, 2, 43.2166666667},
#   {juanjo12x, 2, 47.7333333333},
#   {jafc, 1, 16.25},
#   {Gerard901, 1, 17.6},
#   {Dan212P, 0, 0},
#   {The_Blitz, 0, 0},
#   {itu, 0, 0}],
#  [{hailo, 6, 178.383333333},
#   {kvaleriano, 5, 126.716666667},
#   {Rxcso, 5, 155.583333333},
#   {Slsvcn, 4, 98.7},
#   {kirasam, 4, 121.75},
#   {jael, 4, 126.433333333},
#   {Robert_Alonso, 3, 85.0},
#   {Lucas97, 2, 29.25},
#   {juanjo12x, 2, 47.7333333333},
#   {jafc, 1, 16.25},
#   {Gerard901, 1, 17.6},
#   {Dan212P, 1, 42.05},
#   {The_Blitz, 0, 0},
#   {itu, 0, 0}],
#  [{hailo, 7, 227.666666667},
#   {Rxcso, 7, 255.066666667},
#   {kvaleriano, 6, 174.016666667},
#   {kirasam, 5, 174.233333333},
#   {Slsvcn, 4, 98.7},
#   {jael, 4, 126.433333333},
#   {Robert_Alonso, 4, 133.466666667},
#   {Lucas97, 2, 29.25},
#   {juanjo12x, 2, 47.7333333333},
#   {jafc, 1, 16.25},
#   {Gerard901, 1, 17.6},
#   {Dan212P, 1, 42.05},
#   {The_Blitz, 1, 51.1166666667},
#   {itu, 0, 0}],
#  [{hailo, 8, 282.066666667},
#   {Rxcso, 8, 310.9},
#   {kvaleriano, 6, 174.016666667},
#   {kirasam, 5, 174.233333333},
#   {Robert_Alonso, 5, 189.083333333},
#   {Slsvcn, 4, 98.7},
#   {jael, 4, 126.433333333},
#   {Lucas97, 2, 29.25},
#   {juanjo12x, 2, 47.7333333333},
#   {jafc, 2, 69.6833333333},
#   {The_Blitz, 2, 108.516666667},
#   {Gerard901, 1, 17.6},
#   {Dan212P, 1, 42.05},
#   {itu, 0, 0}],
#  [{hailo, 9, 343.05},
#   {Rxcso, 8, 310.9},
#   {kvaleriano, 7, 236.683333333},
#   {kirasam, 6, 238.166666667},
#   {Slsvcn, 5, 158.666666667},
#   {Robert_Alonso, 5, 189.083333333},
#   {itu, 5, 308.166666667},
#   {jael, 4, 126.433333333},
#   {Lucas97, 3, 87.8666666667},
#   {jafc, 3, 130.7},
#   {juanjo12x, 2, 47.7333333333},
#   {Dan212P, 2, 102.816666667},
#   {The_Blitz, 2, 108.516666667},
#   {Gerard901, 1, 17.6}],
#  [{hailo, 11, 479.933333333},
#   {Rxcso, 9, 379.266666667},
#   {kvaleriano, 8, 305.016666667},
#   {Slsvcn, 6, 224.616666667},
#   {kirasam, 6, 238.166666667},
#   {Robert_Alonso, 6, 255.866666667},
#   {jael, 6, 260.433333333},
#   {itu, 5, 308.166666667},
#   {Lucas97, 4, 157.133333333},
#   {jafc, 3, 130.7},
#   {juanjo12x, 2, 47.7333333333},
#   {Gerard901, 2, 83.3833333333},
#   {Dan212P, 2, 102.816666667},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 12, 552.3},
#   {Rxcso, 10, 454.333333333},
#   {kvaleriano, 9, 377.216666667},
#   {kirasam, 7, 308.333333333},
#   {Robert_Alonso, 7, 329.066666667},
#   {jael, 7, 335.45},
#   {Slsvcn, 6, 224.616666667},
#   {itu, 5, 308.166666667},
#   {Lucas97, 4, 157.133333333},
#   {jafc, 4, 206.45},
#   {juanjo12x, 3, 121.333333333},
#   {Dan212P, 3, 176.416666667},
#   {Gerard901, 2, 83.3833333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 13, 630.25},
#   {Rxcso, 10, 454.333333333},
#   {kvaleriano, 10, 455.283333333},
#   {kirasam, 8, 389.066666667},
#   {Robert_Alonso, 7, 329.066666667},
#   {jael, 7, 335.45},
#   {Slsvcn, 6, 224.616666667},
#   {Lucas97, 5, 235.733333333},
#   {itu, 5, 308.166666667},
#   {juanjo12x, 4, 202.783333333},
#   {jafc, 4, 206.45},
#   {Dan212P, 3, 176.416666667},
#   {Gerard901, 2, 83.3833333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {Rxcso, 12, 621.316666667},
#   {kvaleriano, 11, 539.433333333},
#   {kirasam, 8, 389.066666667},
#   {Robert_Alonso, 8, 411.333333333},
#   {jael, 8, 418.25},
#   {Slsvcn, 6, 224.616666667},
#   {Lucas97, 6, 317.983333333},
#   {jafc, 5, 292.333333333},
#   {itu, 5, 308.166666667},
#   {juanjo12x, 4, 202.783333333},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 2, 83.3833333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {kvaleriano, 13, 719.5},
#   {Rxcso, 12, 621.316666667},
#   {kirasam, 9, 479.883333333},
#   {Robert_Alonso, 9, 500.533333333},
#   {jael, 9, 507.15},
#   {Slsvcn, 8, 406.516666667},
#   {itu, 8, 579.733333333},
#   {Lucas97, 7, 408.066666667},
#   {jafc, 5, 292.333333333},
#   {juanjo12x, 4, 202.783333333},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 2, 83.3833333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {kvaleriano, 13, 719.5},
#   {Rxcso, 12, 621.316666667},
#   {Robert_Alonso, 10, 596.8},
#   {kirasam, 9, 479.883333333},
#   {Slsvcn, 9, 505.016666667},
#   {jael, 9, 507.15},
#   {itu, 9, 675.833333333},
#   {Lucas97, 8, 505.766666667},
#   {jafc, 6, 387.0},
#   {juanjo12x, 5, 296.8},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 3, 178.133333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {kvaleriano, 14, 821.233333333},
#   {Rxcso, 12, 621.316666667},
#   {Robert_Alonso, 11, 701.45},
#   {kirasam, 10, 582.95},
#   {jael, 10, 607.15},
#   {itu, 10, 776.7},
#   {Slsvcn, 9, 505.016666667},
#   {Lucas97, 8, 505.766666667},
#   {jafc, 7, 490.6},
#   {juanjo12x, 6, 398.366666667},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 3, 178.133333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {kvaleriano, 14, 821.233333333},
#   {Rxcso, 12, 621.316666667},
#   {Robert_Alonso, 12, 812.15},
#   {jael, 11, 715.683333333},
#   {itu, 11, 882.916666667},
#   {kirasam, 10, 582.95},
#   {Slsvcn, 9, 505.016666667},
#   {Lucas97, 8, 505.766666667},
#   {jafc, 7, 490.6},
#   {juanjo12x, 7, 503.65},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 3, 178.133333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {kvaleriano, 14, 821.233333333},
#   {Rxcso, 12, 621.316666667},
#   {Robert_Alonso, 12, 812.15},
#   {itu, 12, 998.866666667},
#   {jael, 11, 715.683333333},
#   {kirasam, 10, 582.95},
#   {Slsvcn, 9, 505.016666667},
#   {Lucas97, 9, 617.083333333},
#   {jafc, 8, 602.466666667},
#   {juanjo12x, 8, 616.016666667},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 3, 178.133333333},
#   {The_Blitz, 2, 108.516666667}],
#  [{hailo, 15, 799.083333333},
#   {kvaleriano, 15, 939.483333333},
#   {Robert_Alonso, 13, 930.45},
#   {itu, 13, 1118.66666667},
#   {Rxcso, 12, 621.316666667},
#   {jael, 11, 715.683333333},
#   {kirasam, 10, 582.95},
#   {Slsvcn, 9, 505.016666667},
#   {Lucas97, 9, 617.083333333},
#   {jafc, 8, 602.466666667},
#   {juanjo12x, 8, 616.016666667},
#   {Dan212P, 4, 262.183333333},
#   {Gerard901, 4, 297.133333333},
#   {The_Blitz, 2, 108.516666667}]]

# %%
f = open('../assets/data/7/scoreboard.json', 'w+')
import json
json_data = {
    'contestants': cured,
    'contests': [str(((idx + 1) * (timer/60)))+"'" for idx in  range(len(scoreboards))],
    'scoreboards': [[d.__dict__ for d in score] for score in scoreboards],
}
json.dump(json_data, f)
f.close()

# %%
problems
# Out:
# [u'SP714P01',
#  u'SP714P02',
#  u'SP714P03',
#  u'SP714P04',
#  u'SP714P05',
#  u'SP714P06',
#  u'SP714P07',
#  u'SP714P08',
#  u'SP714P09',
#  u'SP714P10',
#  u'SP714P11',
#  u'SP714P12',
#  u'SP714P13',
#  u'SP714P14',
#  u'SP714P15',
#  u'SP714P16',
#  u'SP714P17',
#  u'SP714P18',
#  u'SP714P19',
#  u'SP714P20']

# %%
3888.0 /60
# Out:
# 64.8
